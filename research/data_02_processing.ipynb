# %%
TRAIN_DIR = "artifacts\data_ingestion\images\train"
TEST_DIR = "artifacts\data_ingestion\images\validation  "

# %%
import os
import pandas as pd
import numpy as np
from cnnClassifier import logger

def create_dataframe(dir):
    image_path = []
    labels = []
    for label in os.listdir(dir):
        for image_name in os.listdir(os.path.join(dir,label)):
            image_path.append(os.path.join(dir,label,image_name))
            labels.append(label)
        print(label, "completed")    
        #logger.info(f"{label} completed")            
    return image_path, labels

# %%
train = pd.DataFrame()
train['image'], train['label']= create_dataframe(TRAIN_DIR)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\arnav\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\arnav\AppData\Local\Temp\ipykernel_5056\4184298510.py", line 2, in <module>
#     train['image'], train['label']= create_dataframe(TRAIN_DIR)
#   File "C:\Users\arnav\AppData\Local\Temp\ipykernel_5056\2408707315.py", line 9, in create_dataframe
#     for label in os.listdir(dir):
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'artifacts\\data_ingestion\\images\train'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\arnav\anaconda3\envs\py310\lib\site-packages\IPython\core\interactiveshell.py", line 2170, in showtraceback
# ...
